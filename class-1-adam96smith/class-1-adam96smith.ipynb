# %%
push!(LOAD_PATH,pwd())
# Out:
# 5-element Array{String,1}:
#  "@"
#  "@v#.#"
#  "@stdlib"
#  "/home/asmith/class-1-adam96smith"
#  "/home/asmith/class-1-adam96smith"

# %%
Task1_plot(30,5)
# Out:
# UndefVarError: Task1_plot not defined
#
# Stacktrace:
#  [1] top-level scope at In[3]:1

# %%
using Starter1
Task1_plot(2,10)
# Out:
# ┌ Info: Precompiling Starter1 [top-level]
# └ @ Base loading.jl:1192

# %%
Task1_plot(10,2)
